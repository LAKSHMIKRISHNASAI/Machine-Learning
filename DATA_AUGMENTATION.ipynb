# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image_path='/content/car.jpg'
image=cv2.imread(image_path)

# %%
def display_image(image, title):
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  plt.title('title')
  plt.axis('off')
  plt.show()

# %%
display_image(image,'original image')

# %% [markdown]
# DATA AUGMENTATION TECHNIQUES

# %%
def rotate_image(image, angle):
  height, width = image.shape[:2]
  rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
  rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
  return rotated_image
rotated_image = rotate_image(image, 25)
display_image(rotated_image, "Rotated Image")

# %%
flipped_image = cv2.flip(image, 1)
display_image(flipped_image, "Horizontally Flipped Image")

# %%
image=cv2.flip(image,1)

# %%
import cv2
from google.colab.patches import cv2_imshow
path = r'/content/car.jpg'

src = cv2.imread(path)
window_name = 'Image'
image = cv2.flip(src, 0)
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=474x294>
# -1

# %%
image=cv2.flip(src,-1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x294>

# %%
image=cv2.blur(src,(9,9))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x294>

# %%
def add_gaussian_noise(image, mean=0, std=10):
  noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
  noisy_image = cv2.add(image, noise)
  return noisy_image
noisy_image = add_gaussian_noise(image)
cv2_imshow(noisy_image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x294>

# %%
def add_gaussian_noise(image, mean=0, std=25):
  noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
  noisy_image = cv2.add(image, noise)
  return noisy_image
noisy_image = add_gaussian_noise(image)
cv2_imshow(noisy_image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x294>

# %%
matrix = np.ones(image.shape, dtype = "uint8") * 120
image = cv2.add(image, matrix)

#image = cv2.subtract(image, matrix)

# %%
plt.imshow(image)
